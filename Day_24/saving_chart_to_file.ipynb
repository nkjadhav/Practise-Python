# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Saving-chart-to-a-file-using-savefig" data-toc-modified-id="Saving-chart-to-a-file-using-savefig-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Saving chart to a file using savefig</a></span></li><li><span><a href="#You-can-also-save-in-pdf-format-and-to-a-different-location-on-your-computer-by-specifying-absolute-path" data-toc-modified-id="You-can-also-save-in-pdf-format-and-to-a-different-location-on-your-computer-by-specifying-absolute-path-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>You can also save in pdf format and to a different location on your computer by specifying absolute path</a></span></li></ul></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Exercise</a></span></li></ul></div>

# %% [markdown]
# <h2 style="color:green" align="center">Saving chart to a file using savefig</h2>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

# %%
plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("piechart.jpg", bbox_inches="tight", pad_inches=1, transparent=True)

# %% [markdown]
# <h2>You can also save in pdf format and to a different location on your computer by specifying absolute path<h2>

# %%
plt.pie(exp_vals,labels=exp_labels,radius=2, autopct='%0.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("piechart.pdf", bbox_inches="tight", pad_inches=10, transparent=True)

# %% [markdown]
# <h1 style="color:red" align="center">Exercise</h1>

# %% [markdown]
# Using following static data for companies revenues,
#
# company=['GOOGL','AMZN','MSFT','FB']
#
# revenue=[90,136,89,27]
#
# 1) Plot a bar chart that looks like below
#
# 2) Save this chart as *jpg file* and then *pdf file* with *5 inch of padding*

# %% [markdown]
# <img align="left" height=300 width=400 src="7_exercise_save_chart.png"/>
