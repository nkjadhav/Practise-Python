# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Matplotlib-Tutorial:-Bar-Chart" data-toc-modified-id="Matplotlib-Tutorial:-Bar-Chart-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Matplotlib Tutorial: Bar Chart</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Simple-bar-chart-showing-revenues-of-major-US-tech-companies" data-toc-modified-id="Simple-bar-chart-showing-revenues-of-major-US-tech-companies-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Simple bar chart showing revenues of major US tech companies</a></span></li><li><span><a href="#Multiple-Bars-showing-revenue-and-profit-of-major-US-tech-companies" data-toc-modified-id="Multiple-Bars-showing-revenue-and-profit-of-major-US-tech-companies-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Multiple Bars showing revenue and profit of major US tech companies</a></span></li><li><span><a href="#Horizontal-bar-chart-using-barh-function" data-toc-modified-id="Horizontal-bar-chart-using-barh-function-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Horizontal bar chart using barh function</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <h1 align="center", style="color:green">Matplotlib Tutorial: Bar Chart</h1>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h3>Simple bar chart showing revenues of major US tech companies</h3>

# %%
company=['IDEA','AIRTEL','RELNC','TATA']
revenue=[90,136,89,27]

# %%
xpos = np.arange(len(company))
print(xpos)
# Out:
# [0 1 2 3]

# %%
plt.bar(xpos,revenue, label="Revenue")
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(xpos,revenue, label="Revenue")

plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('Indian Stocks')
plt.legend()

# %%
#plt.bar(xpos, revenue, label="Revenue")
profit = [40, 20, 34, 12]
plt.xticks(xpos, company)
plt.ylabel("Revenue(Bln)")
plt.title('Indian Stocks')
plt.bar(xpos, revenue, label="Revenue", color="red")
plt.bar(xpos, profit, label="profit")
plt.legend()

# %% [markdown]
# <h3>Multiple Bars showing revenue and profit of major US tech companies</h3>

# %%
profit=[40,20,34,12]

# %%
plt.bar(xpos-0.2,revenue, width=0.4, label="Revenue")
plt.bar(xpos+0.2,profit, width=0.4,label="Profit")
#help(plt.bar)

plt.xticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('Indian Stocks')
plt.legend()

# %% [markdown]
# <h3>Horizontal bar chart using barh function<h3>

# %%
plt.barh(xpos,revenue, label="Revenue")

plt.yticks(xpos,company)
plt.ylabel("Revenue(Bln)")
plt.title('Indian Stocks')
plt.legend()
