# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Matplotlib-Tutorial:-Pie-Charts" data-toc-modified-id="Matplotlib-Tutorial:-Pie-Charts-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Matplotlib Tutorial: Pie Charts</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Draw-pie-chart-to-track-down-home-expenses" data-toc-modified-id="Draw-pie-chart-to-track-down-home-expenses-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Draw pie chart to track down home expenses</a></span></li><li><span><a href="#Draw-pie-chart-as-perfect-circle" data-toc-modified-id="Draw-pie-chart-as-perfect-circle-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Draw pie chart as perfect circle</a></span></li><li><span><a href="#Show-percentages-for-every-pie.-Specify-radius-to-increase-chart-size" data-toc-modified-id="Show-percentages-for-every-pie.-Specify-radius-to-increase-chart-size-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Show percentages for every pie. Specify radius to increase chart size</a></span></li><li><span><a href="#Explode" data-toc-modified-id="Explode-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Explode</a></span></li><li><span><a href="#counterclock-and-angle-properties" data-toc-modified-id="counterclock-and-angle-properties-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>counterclock and angle properties</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <h1 align="center", style="color:green">Matplotlib Tutorial: Pie Charts</h1>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# <h3 style="color:purple">Draw pie chart to track down home expenses</h3>

# %%
exp_vals = [1400, 600, 300, 410, 250]
exp_labels = [
    "Home Rent", "Food", "Phone/Internet Bill", "Car ", "Other Utilities"
]
plt.pie(exp_vals, labels=exp_labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7bebd30>,
# ...
#  [Text(0.0932866,1.09604,'Home Rent'),
#   Text(-0.982218,-0.495224,'Food'),
#   Text(-0.162847,-1.08788,'Phone/Internet Bill'),
#   Text(0.62561,-0.904772,'Car '),
#   Text(1.0615,-0.288458,'Other Utilities')])

# %% [markdown]
# <h3 style="color:purple">Draw pie chart as perfect circle</h3>

# %%
plt.pie(exp_vals, labels=exp_labels, shadow=True)
plt.axis("equal")
plt.show()

# %% [markdown]
# <h3 style="color:purple">Show percentages for every pie. Specify radius to increase chart size</h3>

# %%
plt.axis("equal")
plt.pie(
    exp_vals, labels=exp_labels, shadow=True, autopct='%1.2f%%', radius=1.5)
plt.show()

# %% [markdown]
# <h3 style="color:purple">Explode</h3>

# %%
plt.axis("equal")
plt.pie(
    exp_vals,
    labels=exp_labels,
    shadow=True,
    autopct='%1.1f%%',
    radius=1.5,
    explode=[0, 0, 0, 0.1, 0.2])
plt.show()

# %% [markdown]
# <h3 style="color:purple">counterclock and angle properties</h3>

# %%
plt.axis("equal")
plt.pie(
    exp_vals,
    labels=exp_labels,
    shadow=True,
    autopct='%1.1f%%',
    radius=1.5,
    explode=[0, 0, 0, 0.1, 0.2],
    counterclock=True,
    startangle=90)
plt.show()
